# %%
from langgraph.store.memory import InMemoryStore

# %%
store = InMemoryStore()

# %%
# creating a namespace
namespace = ("user", "u1")

# Adding memories
store.put(namespace, "1", {"data": "User likes pizza"})
store.put(namespace, "2", {"data": "User prefers dark mode"})

# %%
# another namespace
namespace2 = ("user", "u2")

# Add memories
store.put(namespace2, "1", {"data": "User likes pasta"})
store.put(namespace2, "2", {"data": "User prefers grid style navigation"})

# %%
# store.get(namespace, key)
store.get(namespace, "2")
# Out:
# Item(namespace=['user', 'u1'], key='2', value={'data': 'User prefers dark mode'}, created_at='2026-01-08T06:32:30.024816+00:00', updated_at='2026-01-08T06:32:30.024816+00:00')

# %%
items = store.search(namespace)

for item in items:
    print(item.value)
# Out:
# {'data': 'User likes pizza'}
# {'data': 'User prefers dark mode'}

# %%
# !pip install langchain-ollama
from langchain_ollama import OllamaEmbeddings
embeddings = OllamaEmbeddings(model="nomic-embed-text", base_url="http://127.0.0.1:11434")
# Out:
# Collecting langchain-ollama
#   Downloading langchain_ollama-1.0.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-ollama) (1.2.6)
# Collecting ollama<1.0.0,>=0.6.0 (from langchain-ollama)
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.6.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in d:\degree\machinelearning\training\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.25.0)
# Requirement already satisfied: anyio in d:\degree\machinelearning\training\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (4.12.0)
# Requirement already satisfied: certifi in d:\degree\machinelearning\training\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in d:\degree\machinelearning\training\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (1.0.9)
# Requirement already satisfied: idna in d:\degree\machinelearning\training\.venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\degree\machinelearning\training\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\degree\machinelearning\training\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in d:\degree\machinelearning\training\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\degree\machinelearning\training\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\degree\machinelearning\training\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\degree\machinelearning\training\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-ollama) (2.6.2)
# Downloading langchain_ollama-1.0.1-py3-none-any.whl (29 kB)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama, langchain-ollama
#
#    -------------------- ------------------- 1/2 [langchain-ollama]
#    ---------------------------------------- 2/2 [langchain-ollama]
#
# Successfully installed langchain-ollama-1.0.1 ollama-0.6.1

# %%
store = InMemoryStore(index={'embed': embeddings, 'dims':1536})

# %%
namespace = ('users', 'u1')

store.put(namespace, "1", {"data": "User prefers concise answers over long explanations"})
store.put(namespace, "2", {"data": "User likes examples in Python"})
store.put(namespace, "3", {"data": "User usually works late at night"})
store.put(namespace, "4", {"data": "User prefers dark mode in applications"})
store.put(namespace, "5", {"data": "User is learning machine learning"})
store.put(namespace, "6", {"data": "User dislikes overly theoretical explanations"})
store.put(namespace, "7", {"data": "User prefers step-by-step reasoning"})
store.put(namespace, "8", {"data": "User is based in India"})
store.put(namespace, "9", {"data": "User likes real-world analogies"})
store.put(namespace, "10", {"data": "User prefers bullet points over paragraphs"})

# %%
items = store.search(namespace, query="what is the user currently learning", limit=1)

for item in items:
    print(item.value)
# Out:
# {'data': 'User is learning machine learning'}

# %%
items = store.search(namespace, query="what are user's preferences", limit=3)

for item in items:
    print(item.value)
# Out:
# {'data': 'User prefers dark mode in applications'}
# {'data': 'User prefers bullet points over paragraphs'}
# {'data': 'User prefers step-by-step reasoning'}
